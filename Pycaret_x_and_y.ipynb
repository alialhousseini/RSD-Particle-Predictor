# %%
# !pip install pycaret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 484.7/484.7 kB 7.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 11.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 20.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 94.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 9.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 77.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.5/160.5 kB 19.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 15.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 47.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 78.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 6.0 MB/s eta 0:00:00
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import pycaret

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/development.csv')

# %%
df.head()
# Out:
#        x      y   pmax[0]  negpmax[0]   area[0]     tmax[0]    rms[0]  \
# 0  200.0  200.0  4.066907  -17.690173  2.847932    0.600000  2.007042
# 1  200.0  200.0  5.916801   -4.717111  5.792778   79.765174  1.564535
# 2  200.0  200.0  4.286652   -5.316132  2.356390   74.600000  1.404622
# 3  200.0  200.0  4.003635   -4.617459  2.189005   43.000000  1.512162
# 4  200.0  200.0  4.448146   -4.848743  3.997002  196.667482  1.101113
#
#     pmax[1]  negpmax[1]   area[1]  ...    pmax[16]  negpmax[16]    area[16]  \
# 0  5.409161  -17.721210  4.538778  ...  607.109118   -36.282996  583.899899
# 1  4.414289   -4.736827  3.720435  ...  630.348007   -39.715988  580.042799
# 2  4.567191   -5.985437  3.490490  ...  613.880342   -40.679678  580.407491
# 3  5.019058   -4.229949  6.786200  ...  600.714957   -43.206601  579.882635
# 4  3.250262   -5.783587  2.449456  ...  609.723785   -43.570892  590.156125
#
#     tmax[16]   rms[16]    pmax[17]  negpmax[17]    area[17]   tmax[17]  \
# ...

# %%
df.describe()
# Out:
#                    x              y        pmax[0]     negpmax[0]  \
# count  385500.000000  385500.000000  385500.000000  385500.000000
# mean      397.723735     404.106355       4.866423      -5.046162
# std       120.593104     113.652228       1.481220      15.877804
# min       200.000000     200.000000       1.394440   -7741.109923
# 25%       285.000000     310.000000       4.123941      -5.257178
# 50%       400.000000     405.000000       4.668321      -4.646420
# 75%       500.000000     500.000000       5.265888      -4.093211
# max       600.000000     600.000000      20.515415      -0.745816
#
#              area[0]        tmax[0]         rms[0]        pmax[1]  \
# count  385500.000000  385500.000000  385500.000000  385500.000000
# mean        4.330495      97.593811       1.340462      16.510543
# std         3.489414      59.444364       0.342167      16.781018
# min        -0.582573       0.000000       0.275854       2.028134
# ...

# %%
## Assuming that the noise indexes are 0,7,12,15,16,17
ix = 0,7,12,15,16,17
noise = [f"rms[{i}]" for i in ix]
noise += [f"pmax[{i}]" for i in ix]
noise += [f"negpmax[{i}]" for i in ix]
noise += [f"tmax[{i}]" for i in ix]
noise += [f"area[{i}]" for i in ix]

# %%
from pycaret.regression import *
## ignore the features uspposed as noise and y since we are predcitng x
s = setup(df, target = 'x', session_id = 123, ignore_features = (noise + ["y"]))
# Out:
# <style type="text/css">
# #T_d9187_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d9187" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d9187_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d9187_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d9187_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d9187_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_d9187_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_d9187_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d9187_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d9187_row1_col1" class="data row1 col1" >x</td>
#     </tr>
#     <tr>
#       <th id="T_d9187_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
# compare baseline models
best1 = compare_models()
# Out:
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         16:47:22
# Status                    Fitting 10 Folds
# Estimator  Light Gradient Boosting Machine
# <style type="text/css">
# #T_9b5fb th {
#   text-align: left;
# }
# ...

# %%
## ignore the features uspposed as noise and y since we are predcitng y
s = setup(df, target = 'y', session_id = 123, ignore_features = (noise + ["x"]))

# %%
# compare baseline models
best2 = compare_models()
